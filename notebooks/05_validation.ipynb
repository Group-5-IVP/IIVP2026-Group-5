# %%
from tqdm import tqdm
from models import models
from dataset import train_csv_path
from augmentation import augments
from validation import k_fold_validation
import pandas as pd
import numpy as np

# %%
combinations = []
augment_names = ['mild_stroke', 'medium_stroke', 'aggressive_stroke', 'mild_no_stroke', 'medium_no_stroke', 'aggressive_no_stroke']
combination_light = ['scnn_dilated', 'resnet_se']
combination1 = ["scnn_dilated", "resnet_se", "scnn_baseline", "scnn_3conv"]
combination2 = ["scnn_stride", "scnn_dilated", "resnet_se", "resnet_lean"]
combinations.append(combination_light)
combinations.append(combination1)
combinations.append(combination2)

# %%
df_train = pd.read_csv(train_csv_path)

# %%
accuracies = {}
missed = {}
iteration = 0
for c in combinations:
    print("====================================")
    print(f"Iteration {iteration+1}/{len(combinations)}")
    iteration += 1
    m_fn = [models[m] for m in c]
    a_fn = augments['mild_no_stroke']
    acc, df_missed = k_fold_validation(df_train, augm_fn=a_fn, model_fns=m_fn, use_tta=False, k_folds=4, epochs=20, batch_size=128)
    mean = np.mean(acc)
    std = np.std(acc)
    name_mix = f"Ensemble models: {c}, augmentation: mild_no_stroke"
    print(f"{name_mix} results: mean = {mean} , std = {std}")
    accuracies[name_mix] = f"Mean = {str(mean)}, STD = {str(std)}"
    missed[name_mix] = df_missed
print(accuracies)
# Out:
# ====================================
# Iteration 1/3
# Fold 1/4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       6     print(f"Iteration {iteration+1}/{len(combinations)}")
#       7     iteration += 1
#       8     m_fn = [models[m] for m in c]
#       9     a_fn = augments['mild_no_stroke']
# ---> 10     acc, df_missed = k_fold_validation(df_train, augm_fn=a_fn, model_fns=m_fn, use_tta=False, k_folds=4, epochs=20, batch_size=128)
#      11     mean = np.mean(acc)
#      12     std = np.std(acc)
#      13     name_mix = f"Ensemble models: {c}, augmentation: mild_no_stroke"
#
# File ~\PycharmProjects\IIVP2026-Group-5\src\validation.py:37, in k_fold_validation(df, model_fns, augm_fn, use_tta, k_folds, epochs, batch_size, lr)
#      34 train_df = df.iloc[train_idx].reset_index(drop=True)
#      35 val_df = df.iloc[val_idx].reset_index(drop=True)
# ---> 37 evaluation = train_and_evaluate(model_fns, augm_fn, train_df, val_df, epochs, batch_size, lr, use_tta, device)
#      38 fold_accuracies.append(evaluation[0])
#      39 fold_missed.append(evaluation[1])
#
# File ~\PycharmProjects\IIVP2026-Group-5\src\models.py:95, in train_and_evaluate(model_fns, augm_fn, train_df, val_df, epochs, batch_size, lr, use_tta, device)
#      93 models = []
#      94 for fn in model_fns:
# ---> 95     model = train_model(fn, augm_fn = augm_fn, df=train_df, epochs=epochs, lr=lr,
#      96     batch_size=batch_size, device=device,)
#      97     models.append(model)
#      99 return evaluate_model(models=models, val_df=val_df, batch_size=batch_size, use_tta=use_tta)
#
# File ~\PycharmProjects\IIVP2026-Group-5\src\models.py:39, in train_model(model_fn, augm_fn, epochs, seed, df, lr, batch_size, device)
#      32 if device is None:
#      33     device = torch.device(
#      34         'mps' if torch.backends.mps.is_available()
#      35         else 'cuda' if torch.cuda.is_available()
#      36         else 'cpu'
#      37     )
# ---> 39 train_set = DigitDataset(csv_path=train_csv_path,
#      40                          img_path=train_img_folder_path,
#      41                          transform=augm_fn,
#      42                          df=train_df)
#      43 loader = DataLoader(train_set,
#      44                     batch_size=batch_size,
#      45                     shuffle=True,
#      46                     num_workers=2,
#      47                     persistent_workers=True)
#      48 model = model_fn().to(device)
#
# File ~\PycharmProjects\IIVP2026-Group-5\src\dataset.py:21, in DigitDataset.__init__(self, csv_path, img_path, transform, df, preload)
#      19     self.df = df
#      20 if preload and 'Category' in df.columns:
# ---> 21     self.images = [Image.open(f"{img_path}/{int(r.Category)}/{r.Id}.png").convert("L").copy()
#      22                    for r in self.df.itertuples()]
#      23 else:
#      24     self.images = None
#
# File ~\PycharmProjects\IIVP2026-Group-5\.venv\Lib\site-packages\PIL\Image.py:1070, in Image.convert(self, mode, matrix, dither, palette, colors)
#    1018 def convert(
#    1019     self,
#    1020     mode: str | None = None,
#    (...)   1024     colors: int = 256,
#    1025 ) -> Image:
#    1026     """
#    1027     Returns a converted copy of this image. For the "P" mode, this
#    1028     method translates pixels through the palette.  If mode is
#    (...)   1067     :returns: An :py:class:`~PIL.Image.Image` object.
#    1068     """
# -> 1070     self.load()
#    1072     has_transparency = "transparency" in self.info
#    1073     if not mode and self.mode == "P":
#    1074         # determine default mode
#
# File ~\PycharmProjects\IIVP2026-Group-5\.venv\Lib\site-packages\PIL\ImageFile.py:412, in ImageFile.load(self)
#     409         raise OSError(msg)
#     411 b = b + s
# --> 412 n, err_code = decoder.decode(b)
#     413 if n < 0:
#     414     break
#
# KeyboardInterrupt:
